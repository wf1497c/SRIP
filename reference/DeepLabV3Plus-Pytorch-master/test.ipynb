# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./datasets/cityscapes/leftImg8bit/train/bremen/bremen_000000_000019_leftImg8bit.png')

# %%
plt.imshow(img)

# %%
img_blur = cv2.GaussianBlur(img,(11,11),5,5)
plt.imshow(img_blur)
plt.imsave("test.png",img_blur)
